# %%
from bs4 import BeautifulSoup
import requests
print("package imported")
# Out:
# package imported

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
html = requests.get(url)
soup = BeautifulSoup(html.text, 'lxml')

# %%
table = soup.find('table', class_ = "wikitable")

# %%
headlines = table.tbody.tr.text
print(headlines)
# Out:
# Postal code
#
# Borough
#
# Neighborhood

# %%
word = table.tr.text
word = word.split('\n')
word
# Out:
# ['', 'Postal code', '', 'Borough', '', 'Neighborhood', '']

# %%
csv_file = open('postal_code.csv', 'w')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['Postal code', 'Borough', 'Neighborhood'])
# Out:
# 34

# %%
csv_file = open('postal_code.csv', 'w')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['Postal code', 'Borough', 'Neighborhood'])

for datas in table.find_all('tr'):
    data = datas.text.split('\n')
    postal_code = data[1]
    Borough = data[3]
    Neighborhood = data[5]
    print()
    csv_writer.writerow([postal_code, Borough, Neighborhood])
csv_file.close()

# %%
import csv

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("postal_code.csv")
df
# Out:
#      Postal code       Borough  \
# 0    Postal code       Borough
# 1            M1A  Not assigned
# 2            M2A  Not assigned
# 3            M3A    North York
# 4            M4A    North York
# ..           ...           ...
# 176          M5Z  Not assigned
# 177          M6Z  Not assigned
# 178          M7Z  Not assigned
# 179          M8Z     Etobicoke
# 180          M9Z  Not assigned
#
#                                           Neighborhood
# 0                                         Neighborhood
# 1                                                  NaN
# 2                                                  NaN
# 3                                            Parkwoods
# 4                                     Victoria Village
# ..                                                 ...
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# ...
